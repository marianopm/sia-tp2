# %%
"""
seleccion:
    'elitist'
    'roulette_wheel'
    'boltzmann'
    'universal_selection'
    'deterministic_tournament'
    'stochastic_tournament'
    'rank_based'

crossover:
    'one_point'
    'two_point'
    'uniform'
    'annular'

mutation:
    'one_gene'
    'multi_gene'
    'multi_gene_mutation_uniform'
"""

# %%
"""
from mainruns import main
config='config_file.config'
output='datos-Prueba2.csv'
main(config,output)
"""

# %%
from main2 import main

main()
# Out:
# N = 80
# K = 60
# max_generations = 200
#     strength  agility  expertise  resistance  life         height  \
# 0         53        5         77           4    11 1.70000000e+00
# 1         47       19         69           2    13 1.50000000e+00
# 2         56       19         55          13     7 2.00000000e+00
# 3         87        6         34          15     8 1.70000000e+00
# 4         80       20         31          10     9 1.80000000e+00
# ..       ...      ...        ...         ...   ...            ...
# 75         5       32         12          14    87 1.70000000e+00
# 76         7       56          5          31    51 1.80000000e+00
# 77         9        3          4         121    13 1.30000000e+00
# 78         5        6          3          86    50 1.30000000e+00
# 79         6        2          2         137     3 1.70000000e+00
#
#            characterType    performance
# 0   CharacterType.ARCHER 1.01131476e+03
# 1   CharacterType.ARCHER 8.89069372e+02
# 2   CharacterType.ARCHER 8.77468982e+02
# 3   CharacterType.ARCHER 7.50891311e+02
# 4   CharacterType.ARCHER 7.22919389e+02
# ..                   ...            ...
# 75  CharacterType.ARCHER 3.38766388e+01
# 76  CharacterType.ARCHER 3.33806249e+01
# 77  CharacterType.ARCHER 1.39955095e+01
# 78  CharacterType.ARCHER 1.23148080e+01
# 79  CharacterType.ARCHER 4.76566085e+00
#
# [80 rows x 8 columns]
# dentro de Boltzmann, generacion = 1
# T_0= 50
# T_c= 2
# m= 0.02
#          strength        agility      expertise     resistance           life  \
# 0  5.30000000e+01 5.00000000e+00 7.70000000e+01 4.00000000e+00 1.10000000e+01
# 1              53              5             77              4             11
# 2              53              5             77              4             11
# 3              53              5             77              4             11
# 4              53              5             77              4             11
# ..            ...            ...            ...            ...            ...
# 75 6.10000000e+01 1.60000000e+01 2.00000000e+01 2.30000000e+01 2.70000000e+01
# 76 1.50000000e+01 8.00000000e+00 9.50000000e+01 1.60000000e+01 1.40000000e+01
# 77 3.00000000e+01 0.00000000e+00 4.00000000e+01 2.00000000e+01 5.80000000e+01
# 78 1.60000000e+01 2.60000000e+01 7.70000000e+01 1.80000000e+01 9.00000000e+00
# 79 2.20000000e+01 5.90000000e+01 4.50000000e+01 1.30000000e+01 1.00000000e+01
#
#            height         characterType    performance
# 0  1.70000000e+00  CharacterType.ARCHER 1.01131476e+03
# 1  1.70000000e+00  CharacterType.ARCHER 1.01131476e+03
# 2  1.70000000e+00  CharacterType.ARCHER 1.01131476e+03
# 3  1.70000000e+00  CharacterType.ARCHER 1.01131476e+03
# 4  1.70000000e+00  CharacterType.ARCHER 1.01131476e+03
# ..            ...                   ...            ...
# 75 1.90000000e+00  CharacterType.ARCHER 4.10703425e+02
# 76 1.80000000e+00  CharacterType.ARCHER 3.71537647e+02
# 77 1.60000000e+00  CharacterType.ARCHER 3.63996178e+02
# 78 2.00000000e+00  CharacterType.ARCHER 3.57964829e+02
# 79 1.40000000e+00  CharacterType.ARCHER 3.56609697e+02
#
# [80 rows x 8 columns]
# dentro de Boltzmann, generacion = 2
# T_0= 50
# T_c= 2
# m= 0.02
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'numpy.float64' object has no attribute 'exp'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from main2 import main
# ----> 3 main()
#
# File c:\Users\dpenaloza\Downloads\SIA\sia-tp2\main2.py:258, in main()
#     253 #generacion_reemp2 = selection_method(current_generation, k_reemplazo_metodo4, p, p.metodo_reemplazo4, generacion)
#     254
#     255
#     256 # Example BOLTZMANN
#     257 print(current_generation)
# --> 258 generacion_reemp2 = boltzmann_selection(current_generation,k_reemplazo_metodo4,generacion,p.boltzmannT_0,p.boltzmannT_c,p.boltzmannM)
#     263 #print(f'k_reemplazo_metodo3 (k) = {len(generacion_reemp1)}')
#     264 #print(f'k_reemplazo_metodo4 (N - k)= {len(generacion_reemp2)}')
#     265
#     266 # INDIVIDUOS TOTAL
#     267 new_generation = pd.concat([generacion_reemp1, generacion_reemp2])
#
# File c:\Users\dpenaloza\Downloads\SIA\sia-tp2\src\selection.py:136, in boltzmann_selection(population, k, generation, T_0, T_c, m)
#     134 popu = population.loc[:, ['strength','agility','expertise','resistance','life','height','characterType','performance']]
#     135 # Culculate ExpVal and save in 'perfomance'
# --> 136 popu['performance'] = np.exp(popu['performance'] / T) / ( (np.sum(np.exp(popu['performance'] / T))) /len(popu))
#     138 #poblacion_rel_acu = add_relative_accumulate(popu)
#     139 #print(poblacion_rel_acu)
#     141 selected = roulette_wheel_selection(popu, k)
#
# File c:\Users\dpenaloza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:2168, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2164 @final
#    2165 def __array_ufunc__(
#    2166     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2167 ):
# -> 2168     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File c:\Users\dpenaloza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:399, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     396 elif self.ndim == 1:
#     397     # ufunc(series, ...)
#     398     inputs = tuple(extract_array(x, extract_numpy=True) for x in inputs)
# --> 399     result = getattr(ufunc, method)(*inputs, **kwargs)
#     400 else:
#     401     # ufunc(dataframe)
#     402     if method == "__call__" and not kwargs:
#     403         # for np.<ufunc>(..) calls
#     404         # kwargs cannot necessarily be handled block-by-block, so only
#     405         # take this path if there are no kwargs
#
# TypeError: loop of ufunc does not support argument 0 of type numpy.float64 which has no callable exp method

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos desde el archivo CSV
df = pd.read_csv("datos-Prueba1.csv")

# Encontrar el valor máximo y mínimo de la columna 'performance'
max_performance = df['performance'].max()
min_performance = df['performance'].min()

# Graficar
plt.figure(figsize=(10, 6))
plt.scatter(df['generation'], df['performance'], label='Performance', s=3)
plt.scatter(df['generation'].iloc[df['performance'].idxmax()], max_performance, color='red', label='Máximo', s=7)
plt.scatter(df['generation'].iloc[df['performance'].idxmin()], min_performance, color='green', label='Mínimo', s=7)
plt.xlabel('Generación')
plt.ylabel('Performance')
plt.title('Performance por generaciones')
plt.legend()
plt.grid(True)
plt.show()
