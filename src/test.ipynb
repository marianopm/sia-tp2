# %%
from population_init import generate
from character import CharacterType
#from src.stats import random_stats

N = 20
maxStatsValue = 150
type = CharacterType.ARCHER

#equipment_data = random_stats(N, maxStatsValue)
poblacion_inicial = generate(N,maxStatsValue,type)

poblacion_inicial
# Out:
#     equipmentIndex  strength  agility  expertise  resistance  life  height  \
# 6                6        61       17         67           2     3     1.6
# 9                9        89       14         35           6     6     1.9
# 19              19        49       10         61          15    15     2.0
# 15              15        46       10         59          27     8     1.3
# 7                7        58       19         32          26    15     1.5
# 10              10        36       70         34           7     3     1.7
# 11              11        26        4         58          37    25     1.5
# 1                1        47       12         24          64     3     2.0
# 12              12        31       52         30          12    25     1.4
# 13              13        66       24         15          26    19     1.8
# 5                5        42       41         21          40     6     1.5
# ...

# %%
from genes import  encode_genes

cromosomas = encode_genes(poblacion_inicial)
cromosomas
# Out:
#     strength   agility expertise resistance      life height
# 1   00111101  00010001  01000011   00000010  00000011    011
# 2   01011001  00001110  00100011   00000110  00000110    110
# 3   00110001  00001010  00111101   00001111  00001111    111
# 4   00101110  00001010  00111011   00011011  00001000    000
# 5   00111010  00010011  00100000   00011010  00001111    010
# 6   00100100  01000110  00100010   00000111  00000011    100
# 7   00011010  00000100  00111010   00100101  00011001    010
# 8   00101111  00001100  00011000   01000000  00000011    111
# 9   00011111  00110100  00011110   00001100  00011001    001
# 10  01000010  00011000  00001111   00011010  00010011    101
# 11  00101010  00101001  00010101   00101000  00000110    010
# 12  00010110  00100000  00101101   00010010  00100001    100
# 13  00100001  00011001  00010110   00011101  00101001    000
# 14  00010101  00101000  00011111   00001011  00101111    100
# ...

# %%
from genes import decode_genes
cromosomas = decode_genes(poblacion_inicial)
cromosomas
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 from genes import decode_genes
# ----> 2 cromosomas = decode_genes(poblacion_inicial)
#       3 cromosomas
#
# File c:\Users\dpenaloza\Downloads\SIA\sia-tp2\src\genes.py:90, in decode_genes(individuals)
#      87 life = life.apply(lambda x: int(x))
#      89 # Encoding heights:
# ---> 90 height = individuals['height'].apply(lambda x: height_to_dec( x.zfill(3)))
#      92 # Arranging variables into a DataFrame:
#      93 chromosomes = pd.DataFrame({
#      94     'strength': strength,
#      95     'agility': agility,
#    (...)
#      99     'height': height
#     100 })
#
# File c:\Users\dpenaloza\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
# ...

# %%
from genes import norm_genes_dec
cromosomas_dec = norm_genes_dec(poblacion_inicial,1.3,2.0,150)
cromosomas_dec
# Out:
#     strength  agility  expertise  resistance  life  height
# 1         24        1         34          24     4       1
# 2         42        5          7           8    24       0
# 3          6        2         58          15     5       1
# 4         15       15         13          32    11       0
# 5         20       23          8           0    35       1
# 6          8        4         28          32    14       2
# 7         32       34          2           5    12       0
# 8         19       32          6          10    19       0
# 9         38        4          3          30    10       1
# 10        21       41          1          19     4       0
# 11        19       25          3           2    37       2
# 12         6        3         13          40    24       2
# 13         4       37         10          15    21       0
# 14         2       45         19          19     1       0
# 15         8       12          4          51    11       2
# ...

# %%
from genes import encode_norm_genes
cromosomas = encode_norm_genes(poblacion_inicial,130,200,150)
cromosomas
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from genes import encode_norm_genes
#       2 cromosomas = encode_norm_genes(poblacion_inicial,130,200,150)
#       3 cromosomas
#
# ImportError: cannot import name 'encode_norm_genes' from 'genes' (c:\Users\dpenaloza\Downloads\SIA\sia-tp2\src\genes.py)
