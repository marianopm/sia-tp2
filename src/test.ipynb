# %%
from population_init import generate
from character import CharacterType
#from src.stats import random_stats

N = 20
maxStatsValue = 150
type = CharacterType.ARCHER

#equipment_data = random_stats(N, maxStatsValue)
poblacion_inicial = generate(N,maxStatsValue,type)

poblacion_inicial
# Out:
#     equipmentIndex  strength  agility  expertise  resistance  life  height  \
# 6                6         7       45          2          30    66     1.6
# 17              17        83        2          1          30    34     1.5
# 8                8         6       25         11          52    56     1.3
# 18              18         2       12         48          71    17     1.7
# 10              10         3       20         55          48    24     1.9
# 9                9         6       48         37          13    46     1.7
# 15              15        43       27          5          56    19     1.4
# 13              13        19       44         17           9    61     1.3
# 1                1        16       82         18          28     6     1.6
# 3                3        13       75         29          17    16     1.3
# 12              12        43       25          8          44    30     1.9
# 4                4        67       40          3          10    30     2.0
# 0                0       113       14          5           2    16     1.8
# 14              14        33       20         27          48    22     1.6
# 5                5        47       29         17          17    40     1.8
# 2                2        25       20         38          42    25     1.4
# 11              11        22       42         42          26    18     1.7
# 7                7        23       52         48           7    20     1.6
# 16              16        35       15         48          43     9     1.6
# 19              19        66       17         49          15     3     1.8
#
#                     type  performance
# 6   CharacterType.ARCHER    22.662208
# 17  CharacterType.ARCHER    30.311019
# 8   CharacterType.ARCHER    35.507622
# 18  CharacterType.ARCHER    35.809428
# 10  CharacterType.ARCHER    60.058680
# 9   CharacterType.ARCHER    92.280803
# 15  CharacterType.ARCHER   123.499534
# 13  CharacterType.ARCHER   139.428983
# 1   CharacterType.ARCHER   146.281424
# 3   CharacterType.ARCHER   150.882845
# 12  CharacterType.ARCHER   165.801212
# 4   CharacterType.ARCHER   177.679293
# 0   CharacterType.ARCHER   193.783057
# 14  CharacterType.ARCHER   302.870195
# 5   CharacterType.ARCHER   311.900201
# 2   CharacterType.ARCHER   317.024968
# 11  CharacterType.ARCHER   322.629128
# 7   CharacterType.ARCHER   381.030972
# 16  CharacterType.ARCHER   502.772518
# 19  CharacterType.ARCHER   909.756959
